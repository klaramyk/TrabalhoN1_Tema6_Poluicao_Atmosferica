lista_de_listas = [linha.split(',') for linha in linhas]


#Convertendo os dados para um DataFrame
df = pd.Dataframe(lista_de_listas, columns=["Poluente", "Data", "Valor", "Unidade"])

#Calculando os quartis do valor para cada poluente
quartis = df.groupby( "Poluente" )[ "Valor" ].astype(float).quantile([ 0,25 ,  0,5 ,  0,75 ])

# Exibindo os valores baixos, médios e altos para cada poluente
for poluente, q in quartis.groupby(level=0):
    print(f"Poluente: {poluente}")
    print(f"Valor Baixo (<= Q1): {q[0.25]}")
    print(f"Valor Médio (Q1 - Q3): {q[0.5]}")
    print(f"Valor Alto (> Q3): {q[0.75]}")
    print()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1c3d17ccc33f> in <cell line: 150>()
#     148
#     149 #Convertendo os dados para um DataFrame
# --> 150 df = pd.Dataframe(lista_de_listas, columns=["Poluente", "Data", "Valor", "Unidade"])
#     151
#     152 #Calculando os quartis do valor para cada poluente
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %% [markdown]
# Teste 2

# %%
import pandas as pd

# Dados de cada poluente
dados = """
CO,2022-01-01,0.12,ug/m3
CO,2022-01-02,0.48,ug/m3
CO,2022-01-03,0.21,ug/m3
CO,2022-01-04,0.38,ug/m3
CO,2022-01-05,0.22,ug/m3
CO,2022-01-06,0.48,ug/m3
CO,2022-01-07,0.58,ug/m3
CO,2022-01-08,0.41,ug/m3
CO,2022-01-09,0.58,ug/m3
CO,2022-01-10,0.18,ug/m3
CO,2022-01-11,0.29,ug/m3
CO,2022-01-12,0.47,ug/m3
CO,2022-01-13,0.29,ug/m3
CO,2022-01-14,0.22,ug/m3
CO,2022-01-15,0.17,ug/m3
CO,2022-01-16,0.16,ug/m3
CO,2022-01-17,0.16,ug/m3
CO,2022-01-18,0.21,ug/m3
CO,2022-01-19,0.26,ug/m3
CO,2022-01-20,0.36,ug/m3
CO,2022-01-21,0.45,ug/m3
CO,2022-01-22,0.50,ug/m3
CO,2022-01-23,0.58,ug/m3
CO,2022-01-24,0.54,ug/m3
CO,2022-01-25,0.42,ug/m3
CO,2022-01-26,0.38,ug/m3
CO,2022-01-27,0.47,ug/m3
CO,2022-01-28,0.42,ug/m3
CO,2022-01-29,0.46,ug/m3
CO,2022-01-30,0.47,ug/m3
CO,2022-01-31,0.45,ug/m3
MP10,2022-01-01,29.33,ug/m3
MP10,2022-01-03,23.78,ug/m3
MP10,2022-01-04,21.68,ug/m3
MP10,2022-01-05,16.88,ug/m3
MP10,2022-01-06,11.33,ug/m3
MP10,2022-01-07,12.36,ug/m3
MP10,2022-01-08,19.43,ug/m3
MP10,2022-01-09,20.75,ug/m3
MP10,2022-01-10,19.38,ug/m3
MP10,2022-01-11,19.82,ug/m3
MP10,2022-01-12,25.12,ug/m3
MP10,2022-01-13,18.95,ug/m3
MP10,2022-01-14,19.81,ug/m3
MP10,2022-01-15,23.36,ug/m3
MP10,2022-01-16,20.17,ug/m3
MP10,2022-01-17,19.96,ug/m3
MP10,2022-01-18,25.70,ug/m3
MP10,2022-01-19,22.38,ug/m3
MP10,2022-01-20,19.62,ug/m3
MP10,2022-01-21,20.46,ug/m3
MP10,2022-01-22,21.00,ug/m3
MP10,2022-01-23,23.70,ug/m3
SO2,2022-01-17,7.14,ug/m3
SO2,2022-01-18,7.09,ug/m3
SO2,2022-01-19,9.79,ug/m3
SO2,2022-01-20,3.23,ug/m3
SO2,2022-01-21,8.76,ug/m3
SO2,2022-01-22,7.90,ug/m3
SO2,2022-01-23,5.05,ug/m3
SO2,2022-01-24,8.95,ug/m3
SO2,2022-01-25,19.64,ug/m3
SO2,2022-01-26,22.22,ug/m3
SO2,2022-01-27,19.55,ug/m3
SO2,2022-01-28,12.33,ug/m3
SO2,2022-01-29,9.37,ug/m3
SO2,2022-01-30,9.55,ug/m3
SO2,2022-01-31,7.76,ug/m3
"""

# Dividindo os dados em linhas
linhas = dados.strip().split('\n')
# Dividindo cada linha em uma lista de valores
lista_de_listas = [linha.split(',') for linha in linhas]

# Convertendo os dados para um DataFrame
df = pd.DataFrame(lista_de_listas, columns=["Poluente", "Data", "Valor", "Unidade"])

# Convertendo a coluna "Valor" para float
df["Valor"] = df["Valor"].astype(float)

# Calculando os quartis do trimestre para cada poluente
quartis_poluente = df.groupby("Poluente")["Valor"].quantile([0.25, 0.5, 0.75])

# Obtendo os valores baixos, médios e altos para cada poluente
valores_baixos = quartis_poluente.unstack()[0.25]
valores_medios = quartis_poluente.unstack()[0.5]
valores_altos = quartis_poluente.unstack()[0.75]

# Filtrando os dados com base nos quartis
dias_baixos = df[df["Valor"] <= valores_baixos["CO"]]
dias_medios = df[(df["Valor"] > valores_baixos["CO"]) & (df["Valor"] <= valores_altos["CO"])]
dias_altos = df[df["Valor"] > valores_altos["CO"]]

# Exibindo a distribuição dos valores de poluição nos dias classificados como baixos, médios e altos
print("Dias com poluição baixa:")
print(dias_baixos[["Data", "Valor"]])
print("Quantidade de dias com poluição baixa:", len(dias_baixos))
print("\nDias com poluição média:")
print(dias_medios[["Data", "Valor"]])
print("Quantidade de dias com poluição média:", len(dias_medios))
print("\nDias com poluição alta:")
print(dias_altos[["Data", "Valor"]])
print("Quantidade de dias com poluição alta:", len(dias_altos))
# Out:
# Dias com poluição baixa:
#           Data  Valor
# 0   2022-01-01   0.12
# 2   2022-01-03   0.21
# 4   2022-01-05   0.22
# 9   2022-01-10   0.18
# 13  2022-01-14   0.22
# 14  2022-01-15   0.17
# 15  2022-01-16   0.16
# 16  2022-01-17   0.16
# 17  2022-01-18   0.21
# 98  2022-01-19   0.07
# Quantidade de dias com poluição baixa: 10
#
# Dias com poluição média:
#            Data  Valor
# 3    2022-01-04   0.38
# 7    2022-01-08   0.41
# 10   2022-01-11   0.29
# 11   2022-01-12   0.47
# 12   2022-01-13   0.29
# 18   2022-01-19   0.26
# 19   2022-01-20   0.36
# 20   2022-01-21   0.45
# 24   2022-01-25   0.42
# 25   2022-01-26   0.38
# 26   2022-01-27   0.47
# 27   2022-01-28   0.42
# 28   2022-01-29   0.46
# 29   2022-01-30   0.47
# 30   2022-01-31   0.45
# 99   2022-01-20   0.36
# 100  2022-01-21   0.36
# Quantidade de dias com poluição média: 17
#
# Dias com poluição alta:
#            Data  Valor
# 1    2022-01-02   0.48
# 5    2022-01-06   0.48
# 6    2022-01-07   0.58
# ...
